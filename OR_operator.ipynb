# %% [markdown]
# <a href="https://colab.research.google.com/github/shaheerzubery/Deeplearning/blob/main/OR_operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import matplotlib,sys

import numpy as np

def predict(inputs,weights):
	activation=0.0
	for i,w in zip(inputs,weights):
		activation += i*w 
	return 1.0 if activation>=0.0 else -1.0

# each matrix row: up to last row = inputs, last row = y (classification)
def accuracy(matrix,weights):
	num_correct = 0.0
	preds       = []
	for i in range(len(matrix)):
		pred   = predict(matrix[i][:-1],weights) # get predicted classification
		preds.append(pred)
		if pred==matrix[i][-1]: num_correct+=1.0 
	print("Predictions:",preds)
	return num_correct/float(len(matrix))

# each matrix row: up to last row = inputs, last row = y (classification)
def train_weights(matrix,weights,nb_epoch=10,l_rate=0.1,stop_early=True,verbose=True):
	for epoch in range(nb_epoch):
		cur_acc = accuracy(matrix,weights)
		print("\nEpoch %d \nWeights: "%epoch,weights)
		print("Accuracy: ",cur_acc)
		
		if cur_acc==1.0 and stop_early: break 
		
		
		
		for i in range(len(matrix)):
			prediction = predict(matrix[i][:-1],weights) # get predicted classificaion
			error      = matrix[i][-1]-prediction		 # get error from real classification
			if verbose: sys.stdout.write("Training on data at index %d...\n"%(i))
			for j in range(len(weights)): 				 # calculate new weight for each node
				if verbose: sys.stdout.write("\tWeight[%d]: %0.5f --> "%(j,weights[j]))
				weights[j] = weights[j]+(l_rate*error*matrix[i][j]) 
				if verbose: sys.stdout.write("%0.5f\n"%(weights[j]))

	#if len(matrix[0])==4: plot(matrix,weights) # if 2D inputs, excluding bias
	
	return weights 

def main():

	nb_epoch		= 10
	l_rate  		= 0.1
	stop_early 		= True

	part_A = True  

	if part_A: # 3 inputs (including single bias input), 3 weights

				# 	Bias 	i1 		i2 		y
		matrix = [	[1.00,	1.0,	1.0,	1.0],
					[1.00,	0.0,	0.0,	0.0],
					[1.00,	1.0,	0.0,	1.0],
					[1.00,	0.0,	1.0,	1.0]]
		weights= [	 -0.2,	0.0,    0.0		] # initial weights specified in problem

	

	train_weights(matrix,weights=weights,nb_epoch=nb_epoch,l_rate=l_rate,stop_early=stop_early)


if __name__ == '__main__':
	main()
# Out:
# Predictions: [-1.0, -1.0, -1.0, -1.0]
#
# Epoch 0
# Weights:  [-0.2, 0.0, 0.0]
# Accuracy:  0.0
# Training on data at index 0...
# 	Weight[0]: -0.20000 --> 0.00000
# 	Weight[1]: 0.00000 --> 0.20000
# 	Weight[2]: 0.00000 --> 0.20000
# Training on data at index 1...
# 	Weight[0]: 0.00000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 2...
# 	Weight[0]: -0.10000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 3...
# 	Weight[0]: -0.10000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Predictions: [1.0, -1.0, 1.0, 1.0]
#
# Epoch 1
# Weights:  [-0.1, 0.2, 0.2]
# Accuracy:  0.75
# Training on data at index 0...
# 	Weight[0]: -0.10000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 1...
# 	Weight[0]: -0.10000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 2...
# 	Weight[0]: 0.00000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 3...
# 	Weight[0]: 0.00000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Predictions: [1.0, 1.0, 1.0, 1.0]
#
# Epoch 2
# Weights:  [0.0, 0.2, 0.2]
# Accuracy:  0.75
# Training on data at index 0...
# 	Weight[0]: 0.00000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 1...
# 	Weight[0]: 0.00000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 2...
# 	Weight[0]: -0.10000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 3...
# 	Weight[0]: -0.10000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Predictions: [1.0, -1.0, 1.0, 1.0]
#
# Epoch 3
# Weights:  [-0.1, 0.2, 0.2]
# Accuracy:  0.75
# Training on data at index 0...
# 	Weight[0]: -0.10000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 1...
# 	Weight[0]: -0.10000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 2...
# 	Weight[0]: 0.00000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 3...
# 	Weight[0]: 0.00000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Predictions: [1.0, 1.0, 1.0, 1.0]
#
# Epoch 4
# Weights:  [0.0, 0.2, 0.2]
# Accuracy:  0.75
# Training on data at index 0...
# 	Weight[0]: 0.00000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 1...
# 	Weight[0]: 0.00000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 2...
# 	Weight[0]: -0.10000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 3...
# 	Weight[0]: -0.10000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Predictions: [1.0, -1.0, 1.0, 1.0]
#
# Epoch 5
# Weights:  [-0.1, 0.2, 0.2]
# Accuracy:  0.75
# Training on data at index 0...
# 	Weight[0]: -0.10000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 1...
# 	Weight[0]: -0.10000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 2...
# 	Weight[0]: 0.00000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 3...
# 	Weight[0]: 0.00000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Predictions: [1.0, 1.0, 1.0, 1.0]
#
# Epoch 6
# Weights:  [0.0, 0.2, 0.2]
# Accuracy:  0.75
# Training on data at index 0...
# 	Weight[0]: 0.00000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 1...
# 	Weight[0]: 0.00000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 2...
# 	Weight[0]: -0.10000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 3...
# 	Weight[0]: -0.10000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Predictions: [1.0, -1.0, 1.0, 1.0]
#
# Epoch 7
# Weights:  [-0.1, 0.2, 0.2]
# Accuracy:  0.75
# Training on data at index 0...
# 	Weight[0]: -0.10000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 1...
# 	Weight[0]: -0.10000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 2...
# 	Weight[0]: 0.00000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 3...
# 	Weight[0]: 0.00000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Predictions: [1.0, 1.0, 1.0, 1.0]
#
# Epoch 8
# Weights:  [0.0, 0.2, 0.2]
# Accuracy:  0.75
# Training on data at index 0...
# 	Weight[0]: 0.00000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 1...
# 	Weight[0]: 0.00000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 2...
# 	Weight[0]: -0.10000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 3...
# 	Weight[0]: -0.10000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Predictions: [1.0, -1.0, 1.0, 1.0]
#
# Epoch 9
# Weights:  [-0.1, 0.2, 0.2]
# Accuracy:  0.75
# Training on data at index 0...
# 	Weight[0]: -0.10000 --> -0.10000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 1...
# 	Weight[0]: -0.10000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 2...
# 	Weight[0]: 0.00000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
# Training on data at index 3...
# 	Weight[0]: 0.00000 --> 0.00000
# 	Weight[1]: 0.20000 --> 0.20000
# 	Weight[2]: 0.20000 --> 0.20000
